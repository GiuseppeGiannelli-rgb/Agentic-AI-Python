# %%
utente = {
    'name' : 'Giuseppe',
    'surname' : 'Giannelli',
    'age' : 26,
    'work' : {
        'dev' : 'ai coding'

    }
    
    
}

print(utente.get('work').get('dev'))
# Out:
# ai coding

# %%
animals = {'dog', 'cat','wolf'}

print(animals)
# Out:
# {'cat', 'wolf', 'dog'}

# %%
animals = {'dog', 'cat','wolf'}

print(animals)
# Out:
# {'cat', 'wolf', 'dog'}

# %%
min=-5
max=20




for i in range(min,max,3):
    print(i)
# Out:
# -5
# -2
# 1
# 4
# 7
# 10
# 13
# 16
# 19

# %%
def saluta():
    print('hello world')

saluta()
# Out:
# hello world

# %%
x=2
y=5

def sum(a,b):
    return (a+b)+2 

print(sum(x,y))
# Out:
# 9

# %%
a=45
b=33
c=2

def somma(*numbers):
    result=0
    for number in numbers:
        result+= number
        print(result)

somma(a,b,c)
# Out:
# 45
# 78
# 80
